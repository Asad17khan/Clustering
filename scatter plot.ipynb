# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn import processing 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
sc=StandardScaler()
df=pd.read_csv("Outlier_data.csv")
#X=df.columns
fig=plt.figure()
ax = fig.add_subplot(111,projection='3d')
#ax = plt.axes(projection='3d')
#ax.plot3D(xline, yline, zline, 'gray')


df = df.replace('?', 'NONE')
print(df['collision_type'])
ne=LabelEncoder()
f=ne.fit_transform(df['collision_type'])

city=ne.fit_transform(df['incident_city'])
#plot(f,city)
#pyplot.scatter(f,city)
#plt.scatter(f, city, color='k')
ax.scatter3D(f, df['bodily_injuries'], df['age'],c=f, cmap='Greens');
#mean_value=df['collision_type'].mean()
#train['collision_type']=df['collision_type'].fillna(mean_value)
#print(train['collision_type'])
#X_train_std=sc.fit_transform()
#print(X_train_std)
#X_validation_std=sc.transform(X_validation)
# Out:
# 0       Side Collision
# 1                 NONE
# 2       Rear Collision
# 3      Front Collision
# 4                 NONE
#             ...
# 995    Front Collision
# 996     Rear Collision
# 997     Side Collision
# 998     Rear Collision
# 999               NONE
# Name: collision_type, Length: 1000, dtype: object
